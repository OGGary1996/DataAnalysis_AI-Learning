# %% [markdown]
# # 🧭Data Visualization Tutorial
# ## Written by Hongyu Guo
# ## Nov. 10, 2025
# This tutorial demonstrates how to visualize data using **Pandas**, **Matplotlib**, and **Seaborn** — with the **Auto MPG dataset** from the Bokeh module.
#
# We’ll explore:
# - Basic dataset exploration
# - Built-in Pandas plotting
# - Matplotlib visualizations
# - Seaborn advanced plots

# %%
# !pip install bokeh_sampledata
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from bokeh.sampledata.autompg import autompg as df
from scipy.constants import horsepower

# %% [markdown]
# ## 🔍 Step 1: Explore the DataFrame
# Before visualizing, let's understand the data structure.

# %%
df
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0    18.0    8  307.0  130    3504   12.0  70       1
# 1    15.0    8  350.0  165    3693   11.5  70       1
# 2    18.0    8  318.0  150    3436   11.0  70       1
# 3    16.0    8  304.0  150    3433   12.0  70       1
# 4    17.0    8  302.0  140    3449   10.5  70       1
# ..    ...  ...    ...  ...     ...    ...  ..     ...
# 387  27.0    4  140.0   86    2790   15.6  82       1
# 388  44.0    4   97.0   52    2130   24.6  82       2
# 389  32.0    4  135.0   84    2295   11.6  82       1
# 390  28.0    4  120.0   79    2625   18.6  82       1
# 391  31.0    4  119.0   82    2720   19.4  82       1
#
#                           name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ..                         ...
# 387            ford mustang gl
# 388                  vw pickup
# ...

# %%
print("\nSummary Statistics:")
df.describe()
# Out:
# Summary Statistics:
#               mpg         cyl       displ          hp       weight  \
# count  392.000000  392.000000  392.000000  392.000000   392.000000
# mean    23.445918    5.471939  194.411990  104.469388  2977.584184
# std      7.805007    1.705783  104.644004   38.491160   849.402560
# min      9.000000    3.000000   68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000  105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000  151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000  275.750000  126.000000  3614.750000
# max     46.600000    8.000000  455.000000  230.000000  5140.000000
#
#             accel          yr      origin
# count  392.000000  392.000000  392.000000
# mean    15.541327   75.979592    1.576531
# std      2.758864    3.683737    0.805518
# min      8.000000   70.000000    1.000000
# 25%     13.775000   73.000000    1.000000
# 50%     15.500000   76.000000    1.000000
# 75%     17.025000   79.000000    2.000000
# ...

# %% [markdown]
# ## 📊 Step 2: Pandas Built-in Visualization
# Pandas integrates directly with Matplotlib for quick visualizations.

# %% [markdown]
# # **Task 1: Histogram**
#
# ## **A. Improve the Basic Plot**
#
# * Add x-axis label “Miles per Gallon (MPG)”.
# * Add y-axis label “Frequency”.
# * Use 15 bins and change the bar color to “skyblue” with black edges.
# * Increase the figure size to **8×6**.
# * Add a descriptive title and a grid for readability.
#
# ## **B. Add More Data Information**
#
# * Add vertical lines showing the **mean** and **median** MPG.
# * Add a legend explaining each line.
# * Change the number of bins (e.g., 10 vs. 30) and observe how the histogram shape changes.
#
# ## **C. Research & Calculation Questions**
#
# 1. What is a histogram, and what type of data does it visualize?
# 2. How does a histogram compute the height (frequency) of each bar?
# 3. How is **bin width** calculated when using 15 bins?
# 4. Given MPG min = 9 and max = 46, compute the bin width manually for 15 bins.
# 5. How does increasing or decreasing the number of bins change the histogram’s appearance?
# 6. What pattern do you observe about MPG from your histogram?

# %%
# A
# create plot
df['mpg'].plot(kind='hist', figsize=(8,6),color='skyblue',edgecolor='black')
plt.title('Distribution of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
# B
# prepare the mean medium data
mpg_min, mpg_max = df['mpg'].min, df['mpg'].max()
mpg_mean, mpg_medium = df['mpg'].mean(), df['mpg'].median()

# create cart
figure = plt.figure(figsize=(8,6))
plt.hist(df["mpg"], bins=15, color='skyblue', edgecolor='black')
plt.title('Distribution of MPG')
plt.xlabel('MPG')
plt.ylabel('Frequency')
plt.tight_layout()
plt.grid(True)

# add mean and median
plt.axvline(x=mpg_mean, color='red', linestyle='--')
plt.axvline(x=mpg_medium, color='green', linestyle='--')
# legend
plt.legend(['MPG Mean', 'MPG Median', 'MPG'])
plt.show()

# %% [markdown]
# # **Task 2: Scatter plot**
# ## A. Improve the Basic Plot
# * Add x-axis label “Vehicle Weight (lbs)” and y-axis label “Miles per Gallon (MPG)”.
# * Change the color to blue and reduce the transparency (alpha) to 0.4.
# * Increase the figure size to 8×6.
# * Add a grid (horizontal and vertical lines).
# ## B. Add More Data Information
# * Add a third variable using point size (e.g., horsepower or hp).
# * Add a third variable using point color (e.g., cyl for number of cylinders).
# * Add a legend explaining the colors.
# * Add a descriptive title:
# “Relationship Between Car Weight and Fuel Efficiency”.
# ## C. Statistical Enhancements
# * Add a regression line to show the trend.
# * Compute and display the correlation between weight and MPG in the title.
#
# ## D. Discussion Questions
# 1. What is a scatter plot?
# 2. Why do we use scatter plots in data science?
# 3. What type of variables are appropriate for scatter plots (continuous or categorical)?
# 4. How many variables does a scatter plot visualize at the same time?
# 5. What does each point (dot) represent in a scatter plot?
# 6. What would a downward-sloping pattern tell you about weight and MPG?
# 7. If the points were completely scattered randomly, what would that tell you?
# 8. How do we identify a positive relationship between two variables?
# 9. How do we identify a negative relationship?
# 10. What happens if we color points by a third variable (e.g., cylinders)?

# %%
# A basic plot
fig, ax = plt.subplots(figsize=(8,6))
ax.scatter(x=df['weight'], y=df['mpg'], color='green', alpha=0.6)
ax.set_title('Weight vs MPG')
ax.set_xlabel('Weight')
ax.set_ylabel('MPG')
ax.grid(True)
plt.show()

# %%
# B add c(color) and s(size)
figure = plt.figure(figsize=(8,6))
scatter = plt.scatter(df["weight"], df["mpg"], c=df["cyl"], cmap='viridis', s=df['hp']*1.25, alpha=0.5)
plt.colorbar(scatter, label='Cylinders')
plt.title('Weight vs MPG')
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.tight_layout()
plt.show()

# %%
import numpy as np

# correlation
corr = df["weight"].corr(df['mpg'])

# add regression and correlation
fig, ax = plt.subplots(figsize=(8,6))
scatter = ax.scatter(x=df['weight'], y=df['mpg'], c=df['cyl'], cmap='viridis', s=df['hp']*1.25, alpha=0.5)

# color bar
colorbar = fig.colorbar(scatter, ax=ax)
colorbar.set_label('Cylinders')

# add corr to the title
ax.set_title(f"Correlation of Weight vs MPG: {corr:.2f}")
# label
ax.set_xlabel('Weight')
ax.set_ylabel('MPG')

# regression line
# using np.polyfit()
m, b = np.polyfit(df['weight'], df['mpg'], 1)
ax.plot(df['weight'], m*df['weight']+b, color='red', label='Regression Line')

ax.legend()
plt.show()

# %% [markdown]
# # **Task 3: Boxplot**
#
# ## **A. Understanding the Boxplot Structure**
#
# * What does the **box** represent in a boxplot?
# * What do the **lower quartile (Q1)**, **median (Q2)**, and **upper quartile (Q3)** mean?
# * What do the **whiskers** represent?
# * What do **outlier points** represent in a boxplot?
#
# ## **B. Interpreting This Plot**
#
# * How does horsepower change as the number of cylinders increases?
# * Which cylinder group has the **highest median horsepower**?
# * Which cylinder group shows the **largest variability (IQR)** in horsepower?
# * Are there any outliers in any cylinder groups? What might they represent?
#
# ## **C. Comparison Questions**
#
# * Which cylinder group has the **lowest** overall horsepower range?
# * Which group has the **widest** spread between minimum and maximum values?
# * What can you infer about engine size vs. horsepower from this plot?
#
# ## **D. Research & Explanation**
#
# 1. Explain how quartiles (Q1, Q2, Q3) are calculated from data.
# 2. Explain why boxplots are useful for comparing groups (e.g., different cylinder counts).
# 3. How does a boxplot help identify skewness in the distribution?
# 4. In this dataset, is horsepower distribution symmetric or skewed in any cylinder group?

# %%
# Boxplot for horsepower grouped by cylinders
# df.boxplot(column='hp', by='cyl', grid=False, patch_artist=True)
# plt.title('Horsepower by Cylinders')
# plt.suptitle('')
# plt.xlabel('Cylinders')
# plt.ylabel('Horsepower')
# plt.show()
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=df, x='cyl', y='hp')
ax.set_title('Cylinders vs Horsepower')
ax.set_xlabel('Cylinders')
ax.set_ylabel('Horsepower')
ax.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8,6))
sns.set_theme(style="darkgrid")
sns.boxplot(data=df, x='cyl', y='mpg', color='purple', linewidth=1.5, width=0.6, showfliers=True)
ax.set_title('MPG Distribution by Cylinder Count')
ax.set_xlabel('Cylinders')
ax.set_ylabel('MPG')
ax.grid(True)
plt.show()

# %% [markdown]
# ## Below is a comprehensive summary of the most popular and useful values for kind:
#
# Basic Plot Types
#
# | **Kind** | **Description**                            | **Example**                                    |
# | -------- | ------------------------------------------ | ---------------------------------------------- |
# | `'line'` | Default — line plot (good for time series) | `df.plot(kind='line')`                         |
# | `'bar'`  | Vertical bar plot                          | `df.plot(kind='bar', x='origin', y='mpg')`     |
# | `'barh'` | Horizontal bar plot                        | `df.plot(kind='barh', x='origin', y='mpg')`    |
# | `'hist'` | Histogram — distribution of one variable   | `df['mpg'].plot(kind='hist', bins=15)`         |
# | `'box'`  | Boxplot — statistical summary              | `df.plot(kind='box')`                          |
# | `'kde'`  | Kernel Density Estimate (smooth curve)     | `df['mpg'].plot(kind='kde')`                   |
# | `'area'` | Filled area plot                           | `df.plot(kind='area')`                         |
# | `'pie'`  | Pie chart (usually for a Series)           | `df['origin'].value_counts().plot(kind='pie')` |
#
# Scatter & Relationship Plots
#
# | **Kind**    | **Description**                              | **Example**                                                |
# | ----------- | -------------------------------------------- | ---------------------------------------------------------- |
# | `'scatter'` | 2D scatter plot                              | `df.plot(kind='scatter', x='weight', y='mpg')`             |
# | `'hexbin'`  | Hexagonal binning plot — good for dense data | `df.plot(kind='hexbin', x='weight', y='mpg', gridsize=25)` |
#
# Other Less Common (but Useful) Plot Types
# | **Kind**                    | **Description**           | **Example**                                       |
# | --------------------------- | ------------------------- | ------------------------------------------------- |
# | `'density'`                 | Alias for `'kde'`         | `df['mpg'].plot(kind='density')`                  |
# | `'hist'`                    | Histogram, same as before | `df.plot(kind='hist')`                            |
# | `'bar'` with `stacked=True` | Stacked bar plot          | `df[['mpg','hp']].plot(kind='bar', stacked=True)` |

# %% [markdown]
# ## 🎨 Step 3: Matplotlib Visualization
# Matplotlib allows more customization and control over style.

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['weight'], df['mpg'], c=df['cyl'], cmap='viridis', s=60, alpha=0.7)
plt.title('Weight vs MPG Colored by Cylinders')
plt.xlabel('Weight')
plt.ylabel('MPG')
plt.colorbar(label='Cylinders')
plt.show()

plt.figure(figsize=(8,5))
plt.plot(df['yr'], df['mpg'], 'o', alpha=0.5)
plt.title('MPG Across Model Years')
plt.xlabel('Model Year')
plt.ylabel('MPG')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 🌈 Step 4: Seaborn Visualization
# Seaborn provides a higher-level interface and beautiful defaults for statistical plots.

# %%
sns.set_style('whitegrid')

# Pairplot of key variables
sns.pairplot(df[['mpg', 'displ', 'hp', 'weight']], diag_kind='kde')
plt.suptitle('Pairwise Relationships Between Variables', y=1.02)
plt.show()

# %% [markdown]
# # **Task 4: Pairplot**
#
# ## **A. Understanding the Pairplot**
#
# * What is a **pairplot**, and what does it visualize?
# * What does each **scatter plot** in the off-diagonal cells represent?
# * Why are **KDE curves** used on the diagonal?
# * How does a pairplot help us explore relationships between multiple variables at the same time?
#
# ### **Interpretation Questions**
#
# 1. Which variables show a **negative relationship**?
# 2. Which variables show a **positive relationship**?
# 3. How does **MPG** relate to:
#
#    * displacement
#    * horsepower
#    * weight
# 4. Which pair of variables shows the **strongest** visual relationship?
# 5. Which pair shows the **weakest** or no clear trend?
# 6. Are any clusters or patterns visible?
# 7. Are there potential outliers in the scatter plots?
# 8. What does the **shape** of the KDE curve tell us about each variable’s distribution?
#
# ### **Research & Explanation**
#
# * Why is a pairplot more useful than looking at individual scatter plots one by one?
# * How can we detect nonlinear relationships using a pairplot?
# * What might cause two variables to appear uncorrelated even when we expect a relationship?
#
# ---
#
# ## **B. Code Revision Task**
#
# Revise the original code using the instructions below.
#
# ### **1. Improve the Basic Plot**
#
# * Add a title **inside** the pairplot (not with `plt.suptitle`).
# * Increase the figure size.
# * Change diagonal plots from **KDE** to **histograms**, or try another diag mode.
# * Add transparency (`alpha`) to make overlapping points clearer.
#
# ### **2. Add More Data Information**
#
# * Add a **hue** variable (e.g., `cyl`) to color points by category.
# * Customize the color palette (e.g., `"viridis"`, `"coolwarm"`, `"Set2"`).
# * Add different markers for categories.
# * Adjust seaborn theme for better readability.
#
# ### **3. Interpretation Enhancements**
#
# * Add **regression lines** to scatter plots using `kind='reg'`.
# * Use `corner=True` to simplify the plot to a triangle layout.
# * Use `plot_kws` to modify transparency, marker size, or edge color.
#
# ### **4. Code Revision Challenge**
#
# Revise the pairplot so that your final plot includes **at least 5 improvements** from the list above.
# Your revised code must include:
#
# * a **hue** variable
# * a **custom color palette**
# * improved diagonal plots
# * meaningful transparency or markers
# * a clear, descriptive **title**

# %%
# 1. basic plot
sns.pairplot(df[["mpg", "weight", "hp", "displ"]], diag_kind='kde')
plt.show()

# %%
# 2.improve
sns.set_theme(style="whitegrid")

pair = sns.pairplot(df[["mpg", "weight", "hp", "displ"]], diag_kind="hist", plot_kws={"alpha": 0.5})

pair.fig.set_size_inches(12,10)

plt.show()

# %%
# 3. Add more imformation
sns.set_theme(style="darkgrid")

# create charts
pair = sns.pairplot(df[["mpg", "weight", "hp", "displ", "cyl"]], diag_kind="hist", plot_kws={"alpha": 0.5}, hue="cyl", palette="viridis")

# change size
pair.fig.set_size_inches(12,10)

plt.show()

# %%
# 3. Interpretation Enhancements
sns.set_theme(style="whitegrid")
pair = sns.pairplot(df[["mpg", "weight", "hp", "displ", "cyl"]], diag_kind="hist", hue="cyl", palette="viridis", kind="reg", corner=True)
pair.fig.set_size_inches(12,10)
plt.show()

# %% [markdown]
# # **Task 5: Regression Plot (Displacement vs MPG)**
#
#
# ## **A. Understanding the Regression Plot**
#
# * What does a **regression plot** show?
# * What does the **regression line** represent?
# * What does the **shaded confidence interval** tell us?
# * Why is displacement (`displ`) used as the x-variable and MPG as the y-variable in this context?
#
# ## **B. Interpretation Questions**
#
# 1. Is the relationship between displacement and MPG **positive** or **negative**?
# 2. Does the regression line appear steep or shallow? What does that mean?
# 3. How do the scatter points relate to the trend line?
# 4. Are the data points tightly clustered around the line or widely spread?
# 5. What might cause points that fall far away from the trend line?
#
# ## **C. Research & Explanation**
#
# 1. Explain how the linear regression line is computed.
# 2. What does the slope of the regression line represent in this context?
# 3. What does the intercept represent?
# 4. Why is transparency (`alpha=0.6`) useful in scatter plots?
# 5. What additional variables or features might improve this model?
#
# ## **D. Code Revision Task**
#
# Revise the regression plot using the following enhancements:
#
# * Add custom colors for the points and the regression line.
# * Change the marker style or size to improve visibility.
# * Add x- and y-axis labels with units (e.g., “Engine Displacement (L)”).
# * Remove the confidence interval using `ci=None`.
# * Add a grid for readability.
# * Add a text annotation showing the correlation between displacement and MPG.
#
# Your revised code should include at least **three improvements** from the list above.

# %%
# Regression plot for Displacement vs MPG
sns.set_theme(style="whitegrid")
corr = df["displ"].corr(df["mpg"])
fig, ax = plt.subplots(figsize=(8,6))
sns.regplot(data=df, x="displ", y="mpg", scatter_kws=dict(color='green', s=60, alpha=0.6), line_kws=dict(color='red', linewidth=1), ci=None)
ax.set_title("Regression Plot: Displacement vs MPG")
ax.set_xlabel("displ")
ax.set_ylabel("mpg")
ax.grid(True)
plt.show()

# %%
# ------------------------------------------------------
# 6️⃣ Bottle Plot (Boxplot + Swarmplot Overlay)
# ------------------------------------------------------

fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=df, x="cyl", y="mpg", hue="cyl", palette="viridis", dodge=False, width=0.5, legend=False)
sns.swarmplot(data=df, x="cyl", y="mpg", color="black", alpha=0.5, size=4)
ax.set_title("Bottle Plot: MPG Distribution by Cylinders")
ax.set_xlabel("cyl")
ax.set_ylabel("mpg")
ax.legend([],[],frameon=False)
plt.show()

# %% [markdown]
# ✅ Explanation:
#
# hue='cyl' tells Seaborn to apply the palette to that variable explicitly (removing the deprecation warning).
#
# dodge=False ensures all boxes stay aligned vertically (not split).
#
# The swarmplot still shows individual samples for better visualization of distribution.

# %% [markdown]
# # **Task 6: Grouped Bar Chart (Mean Horsepower & Weight by Cylinders)**
#
# In this task, you will create a **grouped bar chart** that compares the **mean horsepower** and **mean weight** across different cylinder groups (4, 6, 8).
# Your goal is to produce a clear and visually appealing figure.
#
# ---
#
# ## **A. Data Preparation**
#
# 1. Group the dataset by `cyl`.
# 2. Calculate the mean horsepower for each cylinder group.
# 3. Calculate the mean weight for each cylinder group.
# 4. Combine these results into a summary table.
#
# ---
#
# ## **B. Plot the Grouped Bar Chart**
#
# Create a grouped bar chart that includes:
#
# * x-axis: cylinder counts (4, 6, 8)
# * bars:
#
#   * bar 1 = mean horsepower
#   * bar 2 = mean weight
# * different colors for each metric
# * clear legend, axis labels, and title
# * readable bar outlines
# * optional: value labels above bars
#
# Use Seaborn's `barplot()` to produce a polished-looking chart.
#
# Title suggestion:
# **"Mean Horsepower and Weight by Cylinder Count"**
#
# ---
#
# ## **C. Improve the Visualization**
#
# * Increase the figure size for clarity.
# * Add bar edge colors for better separation.
# * Add value labels above each bar.
# * Use a modern color palette.
# * Sort cylinder groups properly (4 → 6 → 8).
#
# ---
#
# ## **D. Discussion Questions**
#
# 1. Which cylinder group has the highest **mean horsepower**?
# 2. Which cylinder group has the highest **mean weight**?
# 3. How does the number of cylinders relate to vehicle weight and engine power?
# 4. Why is a grouped bar chart useful when comparing multiple metrics?
# 5. How would the interpretation change if we used **median** instead of mean?

# %%
# A data preparation
# # data group
# grouped = df.groupby("cyl")
# # mean horsepower
# mean_hp = grouped["hp"].mean()
# mean_weight = grouped["weight"].mean()
# # combine mean_hp & mean_weight
# summary = pd.DataFrame({
#     "cyl": mean_hp.index,
#     "mean_hp": mean_hp.values,
#     "mean_weight": mean_weight.values
# })
summary = df.groupby("cyl").agg(mean_hp=("hp","mean"), mean_wt=("weight","mean")).reset_index()

# B Plot the Grouped bar chart
sns.set_theme(style="whitegrid")
x = np.arange(len(summary["cyl"]))
width = 0.4
fig, ax = plt.subplots(figsize=(8,6))
# bar1
ax.bar(x-width/2, summary["mean_hp"], width, color='red', alpha=0.5, label='Mean Horsepower')
# bar2
ax.bar(x+width/2, summary["mean_wt"], width, color='blue', alpha=0.5, label='Mean Weight')

ax.set_xticks(x)
ax.set_xticklabels(summary["cyl"])

ax.set_xlabel('Cylinders')
ax.set_ylabel('Value')
ax.set_title('Mean Horsepower vs Mean Weight by Cylinders')

ax.legend()
plt.show()

# %% [markdown]
# # **Task 7: Pie Chart**
#
# Use the same dataset to visualize the **proportion of cars by cylinder count**.
#
# ## **A. Data Preparation**
#
# * Count how many cars have:
#
#   * 4 cylinders
#   * 6 cylinders
#   * 8 cylinders
#
# ## **B. Create a Pie Chart**
#
# Your pie chart should include:
#
# * A slice for each cylinder category
# * Labels showing the category names
# * Percentage values (use `autopct`)
# * A title:
#   **"Proportion of Cars by Cylinder Count"**
#
# ## **C. Improve the Basic Plot**
#
# * Add custom colors for each slice.
# * Add a small “explode” effect for one category.
# * Ensure the pie chart is circular (use `plt.axis('equal')`).
#
# ## **D. Discussion Questions**
#
# 1. Which cylinder category is most common in the dataset?
# 2. Why might 4-cylinder cars become more common in later years?
# 3. What information does a pie chart convey effectively?
# 4. When is a pie chart **not** an appropriate visualization?

# %%
# A data preparation
counts = df["cyl"].value_counts().sort_index()
print(counts)

# B pie chart
labels = counts.index
sizes = counts.values
fig, ax = plt.subplots(figsize=(8,6))
ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax.set_title("Distribution of Cylinders")
plt.show()
# Out:
# cyl
# 3      4
# 4    199
# 5      3
# 6     83
# 8    103
# Name: count, dtype: int64

# %% [markdown]
# ## ✅ Step 5: Summary
# - Heavier cars tend to have **lower MPG**.
#
# - Cars with more cylinders consume **more fuel**.
#
# - **Seaborn** is great for multi-variable visualizations.
#
# - **Pandas** is perfect for quick data inspection.
#
# - **Matplotlib** allows detailed control and custom styling.

# %% [markdown]
# # Data Visualization Workshop with Auto MPG Dataset
# ### Using Pandas, Matplotlib, and Seaborn
# ### Peer Teaching Activity — 6 Tasks with Full Solutions
#
# Dataset: Auto MPG dataset from `bokeh.sampledata.autompg`
# Goal: Practice core data-visualization concepts and teach them to classmates.

# %%
# Install dependencies if needed
# !pip install bokeh seaborn matplotlib pandas

from bokeh.sampledata.autompg import autompg
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = autompg.copy()
df.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin                       name
# 0  18.0    8  307.0  130    3504   12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165    3693   11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150    3436   11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150    3433   12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140    3449   10.5  70       1                ford torino

# %% [markdown]
# ### Task 1 Objective:
# Create histograms of MPG with different bin sizes.
# Explain how bin width affects interpretation and describe the shape of the distribution.

# %%
plt.figure(figsize=(8,5))
plt.hist(df['mpg'], bins=20, edgecolor='black')
plt.title("MPG Distribution (20 bins)")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(df['mpg'], bins=40, edgecolor='black')
plt.title("MPG Distribution (40 bins)")
plt.xlabel("MPG")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Interpretation
# - The distribution is right-skewed (more low-MPG cars than high-MPG cars).
# - More bins reveal finer structure; fewer bins smooth the shape.
# - Most vehicles achieve 15–30 MPG; few reach 40+ MPG.

# %% [markdown]
# ### Task 2 Objective:
# Create a scatter plot to study the relationship between vehicle weight and fuel efficiency (MPG).
# Add a regression line.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='weight', y='mpg', alpha=0.6)

sns.regplot(data=df, x='weight', y='mpg', scatter=False)

plt.title("Weight vs MPG with Regression Line")
plt.xlabel("Weight")
plt.ylabel("MPG")
plt.show()

# %% [markdown]
# ### Interpretation
# - Strong negative correlation: heavier cars get lower MPG.
# - Regression line shows a clear decreasing trend.
# - Good demonstration of correlation visualization.

# %% [markdown]
# ### Task 4 Objective:
# Overlay swarmplot on a boxplot to show distribution + individual points.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='cyl', y='mpg')
sns.swarmplot(data=df, x='cyl', y='mpg', color='black', alpha=0.6)

plt.title("MPG by Cylinders with Raw Data Points")
plt.xlabel("Cylinders")
plt.ylabel("MPG")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Interpretation
# - Swarmplot reveals the density within each cylinder category.
# - Shows that although boxplots summarize data, individual data patterns matter.

# %% [markdown]
# ### Task 5 Objective:
# Use pairplots to explore relationships across multiple numeric features.

# %%
selected_cols = ['mpg', 'cyl', 'weight']

sns.pairplot(df[selected_cols], diag_kind='kde', plot_kws={'alpha':0.6})
plt.show()

# %% [markdown]
# ### Task 6 Objective:
# Create a heatmap of the correlation matrix to identify strong relationships.

# %%
corr = df.corr(numeric_only=True)

plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# ### Interpretation
# - MPG has strong negative correlation with weight and cylinders.
# - Horsepower and weight are strongly positively correlated.
# - Heatmaps are efficient for scanning many relationships quickly.
